# %% [markdown]
# ## 数据预处理

# %%
import os
import pandas as pd

# 获取当前工作目录
cwd = os.getcwd()

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

# 指定输出目录
output_dir = os.path.join(cwd, 'data_csv')

# 如果输出目录不存在，则创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 指定要读取数据的文件名
data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
# 指定输出文件名
output_file = '即期汇率_美元兑人民币.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

# data_file = '000300.SH-行情统计-20230714.xlsx'
# data_path = os.path.join(data_dir, data_file)
# df = pd.read_excel(data_path)
#df = df.dropna()
# df['交易日期'] = pd.to_datetime(df['交易日期'])
# output_file = '000300.SH-行情统计.csv'
# output_path = os.path.join(output_dir, output_file)
# df.to_csv(output_path, index = None, header = True)

data_file = '沪深300指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '沪深300指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

# data_file = 'SPX.GI-行情统计-20230714.xlsx'
# data_path = os.path.join(data_dir, data_file)
# df = pd.read_excel(data_path)
#df = df.dropna()
# df['交易日期'] = pd.to_datetime(df['交易日期'])
# output_file = 'SPX.GI-行情统计.csv'
# output_path = os.path.join(output_dir, output_file)
# df.to_csv(output_path, index = None, header = True)

data_file = '美国_标准普尔500指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_标准普尔500指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美元指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美元指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = 'MSCI新兴市场.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = 'MSCI新兴市场.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_10年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_10年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_2年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_2年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '中国_银行代客远期结售汇签约差额_人民币_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '中国_银行代客远期结售汇签约差额_人民币_当月值.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '中国_银行结售汇差额_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '中国_银行结售汇差额_当月值.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ## 长线
#
# ### 股票与汇率

# %%
import pandas as pd

# 获取当前工作目录
cwd = os.getcwd()

# 判断是否存在figure文件夹，如果不存在就创建该文件夹
if not os.path.exists('figure'):
    os.makedirs('figure')

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
ER = pd.read_excel(data_path).dropna()
ER.columns = ['Time', 'exRate']
ER['Time'] = pd.to_datetime(ER['Time'])

data_file = '美元指数.xlsx'
data_path = os.path.join(data_dir, data_file)
USDX = pd.read_excel(data_path).dropna()
USDX.columns = ['Time', 'Price_USDX']
USDX['Time'] = pd.to_datetime(USDX['Time'])

# 指定要读取数据的目录
# data_dir = os.path.join(cwd, 'data_csv')

# data_file = '000300.SH-行情统计.csv'
# data_path = os.path.join(data_dir, data_file)
# SH = pd.read_csv(data_path)
# SH = SH.loc[:,['交易日期', '收盘价']].dropna()
# SH.columns = ['Time', 'Price_SH']
# SH['Time'] = pd.to_datetime(SH['Time'])
# SH['Price_SH'] = SH['Price_SH'].str.replace(',', '').astype(float)

data_file = '沪深300指数.xlsx'
data_path = os.path.join(data_dir, data_file)
SH = pd.read_excel(data_path).dropna()
SH.columns = ['Time', 'Price_SH']
SH['Time'] = pd.to_datetime(SH['Time'])

# data_file = 'SPX.GI-行情统计.csv'
# data_path = os.path.join(data_dir, data_file)
# SPX = pd.read_csv(data_path)
# SPX = SPX.loc[:,['交易日期', '收盘价']].dropna()
# SPX.columns = ['Time', 'Price_SPX']
# SPX['Time'] = pd.to_datetime(SPX['Time'])
# SPX['Price_SPX'] = SPX['Price_SPX'].str.replace(',', '').astype(float)

data_file = '美国_标准普尔500指数.xlsx'
data_path = os.path.join(data_dir, data_file)
SPX = pd.read_excel(data_path).dropna()
SPX.columns = ['Time', 'Price_SPX']
SPX['Time'] = pd.to_datetime(SPX['Time'])

data_file = 'MSCI新兴市场.xlsx'
data_path = os.path.join(data_dir, data_file)
MSCI = pd.read_excel(data_path).dropna()
MSCI.columns = ['Time', 'Price_MSCI']
MSCI['Time'] = pd.to_datetime(MSCI['Time'])

Total1 = ER.merge(SH, on='Time') \
    .merge(SPX, on='Time') \
    .merge(USDX, on='Time') \
    .merge(MSCI, on ='Time')

# Calculate stockRate
Total1['stockRate'] = Total1['Price_SPX'] / Total1['Price_SH'] * Total1['exRate']

"""
# Calculate means and standard deviations
mean_exRate = Total1['exRate'].mean()
sd_exRate = Total1['exRate'].std()

mean_stockRate = Total1['stockRate'].mean()
sd_stockRate = Total1['stockRate'].std()

mean_Price_USDX = Total1['Price_USDX'].mean()
sd_Price_USDX = Total1['Price_USDX'].std()

mean_Price_SH = Total1['Price_SH'].mean()
sd_Price_SH = Total1['Price_SH'].std()
"""

# 计算exRate_z
Total1['exRate_z'] = (Total1['exRate'] - Total1['exRate'].mean()) / Total1['exRate'].std()

# 计算USDX_z
Total1['USDX_z'] = (Total1['Price_USDX'] - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std()
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import FuncFormatter
from matplotlib.dates import DateFormatter, MonthLocator

matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus'] =False

# 计算y2
y2 = Total1['exRate_z'] * Total1['stockRate'].std() + Total1['stockRate'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['stockRate'], label='美国标普500/沪深300（以美元计价）', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['stockRate'].mean()) / Total1['stockRate'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('美国标普500/沪深300（以美元计价）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('标普500和沪深300比值与美元兑人民币汇率')

# 保存图片
plt.savefig("figure/标普500和沪深300比值与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['exRate_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 添加参考线
#ax.axhline(y=0, color='gray', linestyle='--')
#ax.axvline(x=pd.to_datetime('2020-01-01'), color='gray', linestyle='--')

# 设置x轴刻度
#ax.xaxis.set_major_locator(plt.MaxNLocator(6))
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('沪深300指数收盘价与美元兑人民币汇率')

#plt.style.use('seaborn-whitegrid')

plt.savefig("figure/沪深300指数收盘价与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_USDX'], label='美元指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('美元指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美元指数收盘价与美元兑人民币汇率')

plt.savefig("figure/美元指数收盘价与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与沪深300指数')

plt.savefig("figure/美元指数与沪深300指数（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_MSCI'].std() + Total1['Price_MSCI'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_MSCI'], label='MSCI新兴市场指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_MSCI'].mean()) / Total1['Price_MSCI'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('MSCI新兴市场指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与MSCI新兴市场指数')

plt.savefig("figure/美元指数与MSCI新兴市场指数（长线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ### 利差与汇率

# %%
# 获取当前工作目录
cwd = os.getcwd()

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
FXRate_table = pd.read_excel(data_path).dropna()
FXRate_table.columns = ['Time', 'US_CHN_rate']
FXRate_table['Time'] = pd.to_datetime(FXRate_table['Time'])

data_file = '美国_国债收益率_10年.xlsx'
data_path = os.path.join(data_dir, data_file)
US_Y10_table = pd.read_excel(data_path).dropna()
US_Y10_table.columns = ['Time', 'US_Y10']
US_Y10_table['Time'] = pd.to_datetime(US_Y10_table['Time'])

data_file = '美国_国债收益率_2年.xlsx'
data_path = os.path.join(data_dir, data_file)
US_Y2_table = pd.read_excel(data_path).dropna()
US_Y2_table.columns = ['Time', 'US_Y2']
US_Y2_table['Time'] = pd.to_datetime(US_Y2_table['Time'])

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_csv')

data_file = '中国十年期国债收益率历史数据.csv'
data_path = os.path.join(data_dir, data_file)
CHN_Y10_table = pd.read_csv(data_path)
CHN_Y10_table = CHN_Y10_table.iloc[:,0:2].dropna()
CHN_Y10_table.columns = ['Time', 'CHN_Y10']
CHN_Y10_table['Time'] = pd.to_datetime(CHN_Y10_table['Time'])

data_file = '中国二年期国债收益率历史数据.csv'
data_path = os.path.join(data_dir, data_file)
CHN_Y2_table = pd.read_csv(data_path)
CHN_Y2_table = CHN_Y2_table.iloc[:,0:2].dropna()
CHN_Y2_table.columns = ['Time', 'CHN_Y2']
CHN_Y2_table['Time'] = pd.to_datetime(CHN_Y2_table['Time'])

# 计算yearly_change_rate
FXRate_table['yearly_change_rate'] = (FXRate_table['US_CHN_rate'] - FXRate_table['US_CHN_rate'].shift(365)) / FXRate_table['US_CHN_rate'].shift(365)

# 删除缺失值
US_CHN_rate_table = FXRate_table.dropna()

# 合并数据框
Total2 = US_CHN_rate_table.merge(US_Y10_table, on='Time') \
    .merge(US_Y2_table, on='Time') \
    .merge(CHN_Y10_table, on='Time') \
    .merge(CHN_Y2_table, on='Time')

# 计算新变量
Total2['interest_spread_Y10'] = Total2['US_Y10'] - Total2['CHN_Y10']
Total2['interest_spread_Y2'] = Total2['US_Y2'] - Total2['CHN_Y2']
Total2['interest_spread_Y10_mod'] = Total2['US_Y10'] - Total2['CHN_Y10'] - Total2['yearly_change_rate']
Total2['interest_spread_Y2_mod'] = Total2['US_Y2'] - Total2['CHN_Y2'] - Total2['yearly_change_rate']

"""
mean_interest_spread_Y10 = Total2["interest_spread_Y10"].mean()
sd_interest_spread_Y10 = Total2["interest_spread_Y10"].std()

mean_interest_spread_Y2 = Total2["interest_spread_Y2"].mean()
sd_interest_spread_Y2 = Total2["interest_spread_Y2"].std()

mean_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].mean()
sd_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].std()

mean_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].mean()
sd_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].std()

mean_US_CHN_rate = Total2["US_CHN_rate"].mean()
sd_US_CHN_rate = Total2["US_CHN_rate"].std()
"""

# 计算US_CHN_rate_z
Total2['US_CHN_rate_z'] = (Total2['US_CHN_rate'] - Total2['US_CHN_rate'].mean()) / Total2['US_CHN_rate'].std()
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10'].std() + Total2['interest_spread_Y10'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10'], label='美中10年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10'].mean()) / Total2['interest_spread_Y10'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10_mod'].std() + Total2['interest_spread_Y10_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10_mod'], label='美中10年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10_mod'].mean()) / Total2['interest_spread_Y10_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2'].std() + Total2['interest_spread_Y2'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2'], label='美中2年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2'].mean()) / Total2['interest_spread_Y2'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2_mod'].std() + Total2['interest_spread_Y2_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2_mod'].mean()) / Total2['interest_spread_Y2_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ## 短线
#
# ### 股票与汇率

# %%
split_year = 2020

ER = ER[ER['Time'].dt.year >= split_year]
USDX = USDX[USDX['Time'].dt.year >= split_year]
SH = SH[SH['Time'].dt.year > split_year]
SPX = SPX[SPX['Time'].dt.year > split_year]
MSCI = MSCI[MSCI['Time'].dt.year > split_year]

Total1 = ER.merge(SH, on='Time') \
    .merge(SPX, on='Time') \
    .merge(USDX, on='Time') \
    .merge(MSCI, on='Time')

# Calculate stockRate
Total1['stockRate'] = Total1['Price_SPX'] / Total1['Price_SH'] * Total1['exRate']

"""
# Calculate means and standard deviations
mean_exRate = Total1['exRate'].mean()
sd_exRate = Total1['exRate'].std()

mean_stockRate = Total1['stockRate'].mean()
sd_stockRate = Total1['stockRate'].std()

mean_Price_USDX = Total1['Price_USDX'].mean()
sd_Price_USDX = Total1['Price_USDX'].std()

mean_Price_SH = Total1['Price_SH'].mean()
sd_Price_SH = Total1['Price_SH'].std()
"""

# 计算exRate_z
Total1['exRate_z'] = (Total1['exRate'] - Total1['exRate'].mean()) / Total1['exRate'].std()

# 计算USDX_z
Total1['USDX_z'] = (Total1['Price_USDX'] - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['stockRate'].std() + Total1['stockRate'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['stockRate'], label='美国标普500/沪深300（以美元计价）', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['stockRate'].mean()) / Total1['stockRate'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('美国标普500/沪深300（以美元计价）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('标普500和沪深300比值与美元兑人民币汇率')

plt.savefig("figure/标普500和沪深300比值与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['exRate_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 添加参考线
#ax.axhline(y=0, color='gray', linestyle='--')
#ax.axvline(x=pd.to_datetime('2020-01-01'), color='gray', linestyle='--')

# 设置x轴刻度
#ax.xaxis.set_major_locator(plt.MaxNLocator(6))
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('沪深300指数收盘价与美元兑人民币汇率')

#plt.style.use('seaborn-whitegrid')

plt.savefig("figure/沪深300指数收盘价与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_USDX'], label='美元指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('美元指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美元指数收盘价与美元兑人民币汇率')

plt.savefig("figure/美元指数收盘价与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与沪深300指数')

plt.savefig("figure/美元指数与沪深300指数（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_MSCI'].std() + Total1['Price_MSCI'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_MSCI'], label='MSCI新兴市场指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_MSCI'].mean()) / Total1['Price_MSCI'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('MSCI新兴市场指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与MSCI新兴市场指数')

plt.savefig("figure/美元指数与MSCI新兴市场指数（短线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ### 利差与汇率

# %%
FXRate_table = FXRate_table[FXRate_table['Time'].dt.year >= split_year]
US_Y10_table = US_Y10_table[US_Y10_table['Time'].dt.year >= split_year]
US_Y2_table = US_Y2_table[US_Y2_table['Time'].dt.year >= split_year]
CHN_Y10_table = CHN_Y10_table[CHN_Y10_table['Time'].dt.year >= split_year]
CHN_Y2_table = CHN_Y2_table[CHN_Y2_table['Time'].dt.year >= split_year]

# 计算yearly_change_rate
FXRate_table['yearly_change_rate'] = (FXRate_table['US_CHN_rate'] - FXRate_table['US_CHN_rate'].shift(365)) / FXRate_table['US_CHN_rate'].shift(365)

# 删除缺失值
US_CHN_rate_table = FXRate_table.dropna()

# 合并数据框
Total2 = US_CHN_rate_table.merge(US_Y10_table, on='Time') \
    .merge(US_Y2_table, on='Time') \
    .merge(CHN_Y10_table, on='Time') \
    .merge(CHN_Y2_table, on='Time')

# 计算新变量
Total2['interest_spread_Y10'] = Total2['US_Y10'] - Total2['CHN_Y10']
Total2['interest_spread_Y2'] = Total2['US_Y2'] - Total2['CHN_Y2']
Total2['interest_spread_Y10_mod'] = Total2['US_Y10'] - Total2['CHN_Y10'] - Total2['yearly_change_rate']
Total2['interest_spread_Y2_mod'] = Total2['US_Y2'] - Total2['CHN_Y2'] - Total2['yearly_change_rate']

"""
mean_interest_spread_Y10 = Total2["interest_spread_Y10"].mean()
sd_interest_spread_Y10 = Total2["interest_spread_Y10"].std()

mean_interest_spread_Y2 = Total2["interest_spread_Y2"].mean()
sd_interest_spread_Y2 = Total2["interest_spread_Y2"].std()

mean_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].mean()
sd_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].std()

mean_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].mean()
sd_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].std()

mean_US_CHN_rate = Total2["US_CHN_rate"].mean()
sd_US_CHN_rate = Total2["US_CHN_rate"].std()
"""

# 计算US_CHN_rate_z
Total2['US_CHN_rate_z'] = (Total2['US_CHN_rate'] - Total2['US_CHN_rate'].mean()) / Total2['US_CHN_rate'].std()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10'].std() + Total2['interest_spread_Y10'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10'], label='美中10年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10'].mean()) / Total2['interest_spread_Y10'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10_mod'].std() + Total2['interest_spread_Y10_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10_mod'], label='美中10年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10_mod'].mean()) / Total2['interest_spread_Y10_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2'].std() + Total2['interest_spread_Y2'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2'].mean()) / Total2['interest_spread_Y2'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2_mod'].std() + Total2['interest_spread_Y2_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2_mod'].mean()) / Total2['interest_spread_Y2_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ## 结售汇与人民币汇率

# %%
from sklearn.preprocessing import scale

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
FXRate_table = pd.read_excel(data_path).dropna()
FXRate_table.columns = ['Time', 'FXRate']
FXRate_table['Time'] = pd.to_datetime(FXRate_table['Time'])

FXRate_table['year'] = FXRate_table['Time'].dt.year
FXRate_table['month'] = FXRate_table['Time'].dt.month
FXRate_table['year_month'] = FXRate_table['year'].astype(str) + '-' + FXRate_table['month'].astype(str)
FXRate_table['year_month'] = pd.to_datetime(FXRate_table['year_month'])
FXRate_table_monthly = FXRate_table.loc[FXRate_table.groupby(['year', 'month'])['Time'].idxmax()]

data_file = '中国_银行代客远期结售汇签约差额_人民币_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
FX_Contract_Difference_table = pd.read_excel(data_path).dropna()
FX_Contract_Difference_table.columns = ['Time', 'FX_Contract_Difference']
FX_Contract_Difference_table['Time'] = pd.to_datetime(FX_Contract_Difference_table['Time'])

FX_Contract_Difference_table['year'] = FX_Contract_Difference_table['Time'].dt.year
FX_Contract_Difference_table['month'] = FX_Contract_Difference_table['Time'].dt.month
FX_Contract_Difference_table['year_month'] = FX_Contract_Difference_table['year'].astype(str) + '-' + FX_Contract_Difference_table['month'].astype(str)
FX_Contract_Difference_table['year_month'] = pd.to_datetime(FX_Contract_Difference_table['year_month'])

#merged_table = pd.merge(FXRate_table_monthly, FX_Contract_Difference_table, on='year_month')
#merged_table = merged_table[['year_month', 'FX_Contract_Difference', 'FXRate']]
#merged_table['FXRate_z'] = scale(merged_table['FXRate'])

mean_FX_Contract_Difference = FX_Contract_Difference_table['FX_Contract_Difference'].mean()
sd_FX_Contract_Difference = FX_Contract_Difference_table['FX_Contract_Difference'].std()

mean_FXRate = FXRate_table_monthly['FXRate'].mean()
sd_FXRate = FXRate_table_monthly['FXRate'].std()

FXRate_table_monthly['FXRate_z'] = scale(FXRate_table_monthly['FXRate'])
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 计算y2
y2 = -FXRate_table_monthly['FXRate_z'] * FX_Contract_Difference_table['FX_Contract_Difference'].std() + FX_Contract_Difference_table['FX_Contract_Difference'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.bar(FX_Contract_Difference_table['year_month'], FX_Contract_Difference_table['FX_Contract_Difference'], label='差额', color='#6495ED', alpha = 0.7, width=20)
ax.plot(FXRate_table_monthly['year_month'], y2, label='美元/人民币', color='#ea9c9d', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + FX_Contract_Difference_table['FX_Contract_Difference'].mean()) / FX_Contract_Difference_table['FX_Contract_Difference'].std() * FXRate_table_monthly['FXRate'].std() + FXRate_table_monthly['FXRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('差额')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('当月银行代客远期结售汇签约差额（亿元）')

plt.savefig("figure/银行代客远期结售汇签约差额与美元兑人民币汇率.png")

# 显示图形
plt.show()

# %%
data_file = '中国_银行结售汇差额_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
Exchange_Rate_Spread_table = pd.read_excel(data_path).dropna()
Exchange_Rate_Spread_table.columns = ['Time', 'Exchange_Rate_Spread']
Exchange_Rate_Spread_table['Time'] = pd.to_datetime(Exchange_Rate_Spread_table['Time'])

Exchange_Rate_Spread_table['year'] = Exchange_Rate_Spread_table['Time'].dt.year
Exchange_Rate_Spread_table['month'] = Exchange_Rate_Spread_table['Time'].dt.month
Exchange_Rate_Spread_table['year_month'] = Exchange_Rate_Spread_table['year'].astype(str) + '-' + Exchange_Rate_Spread_table['month'].astype(str)
Exchange_Rate_Spread_table['year_month'] = pd.to_datetime(Exchange_Rate_Spread_table['year_month'])
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 计算y2
y2 = -FXRate_table_monthly['FXRate_z'] * Exchange_Rate_Spread_table['Exchange_Rate_Spread'].std() + Exchange_Rate_Spread_table['Exchange_Rate_Spread'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.bar(Exchange_Rate_Spread_table['year_month'], Exchange_Rate_Spread_table['Exchange_Rate_Spread'], label='差额', color='#6495ED', alpha = 0.7, width=20)
ax.plot(FXRate_table_monthly['year_month'], y2, label='美元/人民币', color='#ea9c9d', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Exchange_Rate_Spread_table['Exchange_Rate_Spread'].mean()) / Exchange_Rate_Spread_table['Exchange_Rate_Spread'].std() * FXRate_table_monthly['FXRate'].std() + FXRate_table_monthly['FXRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('差额')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('当月银行结售汇差额（亿美元）')

plt.savefig("figure/银行结售汇差额与美元兑人民币汇率.png")

# 显示图形
plt.show()

# %%
FXRate_table1 = FXRate_table.set_index('Time', inplace=False)
FXRate_table_monthly1 = FXRate_table1.resample('M').last()

# 指定输出目录
output_dir = os.path.join(cwd, 'data_csv')
# 指定输出文件名
output_file = '即期汇率_美元兑人民币（月）.csv'
output_path = os.path.join(output_dir, output_file)
FXRate_table_monthly1.to_csv(output_path)

FXRate_table_monthly1 = pd.read_csv("data_csv/即期汇率_美元兑人民币（月）.csv")
FXRate_table_monthly1['Time'] = pd.to_datetime(FXRate_table_monthly1['Time'])

merged_table = pd.merge(FXRate_table_monthly1, FX_Contract_Difference_table, on = 'Time', how = 'outer')
merged_table = pd.merge(merged_table, Exchange_Rate_Spread_table, on = 'Time', how = 'outer')

from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line
from pyecharts.commons.utils import JsCode

# 将日期格式化为年月字符串
formatted_date_data = [date.strftime("%Y-%m") for date in merged_table['Time']]

bar = (
    Bar()
    .add_xaxis(formatted_date_data)
    .add_yaxis(
        "银行结售汇差额",
        merged_table['FX_Contract_Difference'].tolist(),
        yaxis_index=0,
        itemstyle_opts=opts.ItemStyleOpts(color='#93cc82',opacity=0.7),
    )
    .add_yaxis(
        "银行代客远期结售汇签约差额",
        merged_table['Exchange_Rate_Spread'].tolist(),
        yaxis_index=1,
        itemstyle_opts=opts.ItemStyleOpts(color='#5793f3',opacity=0.7),
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="代客远期结售汇签约差额（亿元）",
            name_location='middle',
            name_gap=50,
            min_=Exchange_Rate_Spread_table['Exchange_Rate_Spread'].mean() - 5.7*Exchange_Rate_Spread_table['Exchange_Rate_Spread'].std(),
            max_=Exchange_Rate_Spread_table['Exchange_Rate_Spread'].mean() + 5.7*Exchange_Rate_Spread_table['Exchange_Rate_Spread'].std(),
            type_="value",
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#5793f3")
            ),
            axislabel_opts=opts.LabelOpts(
                formatter=JsCode("function(value){return value.toFixed(0)}")
            ),
        )
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="汇率",
            name_location='middle',
            name_gap=30,
            min_=FXRate_table_monthly1['FXRate'].mean() - 5.7*FXRate_table_monthly1['FXRate'].std(),
            max_=FXRate_table_monthly1['FXRate'].mean() + 5.7*FXRate_table_monthly1['FXRate'].std(),
            interval=0.5,
            position="left",
            is_inverse=True,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color='#db6968')
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
            axislabel_opts=opts.LabelOpts(
                formatter=JsCode("function(value){return value.toFixed(2)}")
            ),
        )
    )
    .set_global_opts(
        #xaxis_opts=opts.AxisOpts(
            #axislabel_opts=opts.LabelOpts(formatter=JsCode("function (value) { return value.slice(0, 7); }"))
        #),
        yaxis_opts=opts.AxisOpts(
            name="结售汇差额（亿美元）",
            name_location='middle',
            name_gap=50,
            type_="value",
            min_=FX_Contract_Difference_table['FX_Contract_Difference'].mean() - 5.7*FX_Contract_Difference_table['FX_Contract_Difference'].std(),
            max_=FX_Contract_Difference_table['FX_Contract_Difference'].mean() + 5.7*FX_Contract_Difference_table['FX_Contract_Difference'].std(),
            position="right",
            offset=80,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color='#93cc82')
            ),
            axislabel_opts=opts.LabelOpts(
                formatter=JsCode("function(value){return value.toFixed(0)}")
            ),
        ),
        #title_opts=opts.TitleOpts(title="Grid-多 Y 轴示例"),
        #tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        datazoom_opts=[
            opts.DataZoomOpts(
                is_show=True, type_="inside", xaxis_index=[0, 0],#filter_mode = 'weakFilter',
                ),
                opts.DataZoomOpts(
                    is_show=True, type_="slider",xaxis_index=[0, 0], pos_top="93%",#filter_mode = 'weakFilter',
                    ),
                # opts.DataZoomOpts(
                #   is_show=True, type_="slider",orient= "vertical",yaxis_index=[0, 0,1],range_start= -10,range_end=110
                #   ),
                ],
        tooltip_opts=opts.TooltipOpts(
            trigger="axis",
            axis_pointer_type="cross",
            background_color="rgba(245, 245, 245, 0.8)",
            border_width=1,
            border_color="#ccc",
            textstyle_opts=opts.TextStyleOpts(color="#000"),
            ),
        axispointer_opts=opts.AxisPointerOpts(
            is_show=True, link=[{"xAxisIndex": [0]},{"yAxisIndex": [0]},]
            ),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)

line = (
    Line()
    .add_xaxis(formatted_date_data)
    .add_yaxis(
        "美元/人民币",
        merged_table['FXRate'],
        yaxis_index=2,
        color='#db6968',
        label_opts=opts.LabelOpts(is_show=False),
    )
)

bar.overlap(line)
grid = Grid()
grid.add(bar, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="26ec003db6074d72bcdbb90905905a29" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_26ec003db6074d72bcdbb90905905a29 = echarts.init(
#                     document.getElementById('26ec003db6074d72bcdbb90905905a29'), 'white', {renderer: 'canvas'});
#                 var option_26ec003db6074d72bcdbb90905905a29 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#db6968",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u94f6\u884c\u7ed3\u552e\u6c47\u5dee\u989d",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 289.50636,
#                 105.025818,
#                 518.848285,
#                 614.179393,
#                 -262.687908,
#                 -17.18576,
#                 252.372413,
#                 652.289066,
#                 71.722393,
#                 978.48765,
#                 51.882938,
#                 21.018226,
#                 495.415107,
#                 224.016128,
#                 -43.500706,
#                 357.013159,
#                 -142.099903,
#                 -119.707209,
#                 10.514068,
#                 462.056172,
#                 -124.729855,
#                 -333.362412,
#                 -22.973171,
#                 -1012.298913,
#                 216.402373,
#                 363.025754,
#                 210.102575,
#                 -110.727919,
#                 -337.024526,
#                 -676.306152,
#                 -215.809685,
#                 -74.230409,
#                 -359.912651,
#                 -39.14447,
#                 341.081817,
#                 598.436111,
#                 589.579965,
#                 160.121076,
#                 277.387014,
#                 568.950347,
#                 646.706312,
#                 888.734965,
#                 159.44398,
#                 575.840853,
#                 1109.384644,
#                 797.931068,
#                 1253.158757,
#                 1129.923442,
#                 1547.623179,
#                 1389.79276,
#                 165.110083,
#                 90.497683,
#                 53.082156,
#                 -165.06,
#                 60.477997,
#                 349.233941,
#                 -386.194643,
#                 -111.76548,
#                 119.652335,
#                 314.349351,
#                 -359.355378,
#                 -941.659153,
#                 -1587.769991,
#                 -421.685424,
#                 -380.080174,
#                 -516.282631,
#                 -975.396507,
#                 -4284.3292,
#                 -980.914645,
#                 -109.369237,
#                 -429.348861,
#                 -1150.992669,
#                 -1621.330629,
#                 -398.766107,
#                 -352.609143,
#                 -81.064538,
#                 86.070801,
#                 -54.921789,
#                 -534.378299,
#                 -122.424501,
#                 -750.172147,
#                 -261.69789,
#                 -687.471651,
#                 -885.034257,
#                 -549.287487,
#                 320.968057,
#                 -9.010102,
#                 349.698866,
#                 235.429636,
#                 302.746447,
#                 177.25145,
#                 205.792469,
#                 -495.119268,
#                 -414.049286,
#                 -792.032639,
#                 -1021.568848,
#                 -729.605846,
#                 -279.058559,
#                 -126.679604,
#                 316.759842,
#                 106.225929,
#                 -887.043338,
#                 -1028.176877,
#                 -368.9189,
#                 17.6027,
#                 190.7503,
#                 319.4772,
#                 662.625436,
#                 451.012612,
#                 644.481493,
#                 1224.651213,
#                 963.448301,
#                 1312.412111,
#                 669.321298,
#                 776.485573,
#                 777.549134,
#                 383.963323,
#                 764.096311,
#                 949.157259,
#                 1077.163275,
#                 622.211829,
#                 1100.911064,
#                 1165.082579,
#                 292.741828,
#                 541.395091,
#                 381.875747,
#                 594.105137,
#                 780.84,
#                 779.634246,
#                 741.975189,
#                 990.999323,
#                 2279.871172,
#                 782.795102,
#                 986.249663,
#                 425.417124,
#                 166.667292,
#                 1364.565559,
#                 960.12703,
#                 351.146768,
#                 -184.849572,
#                 253.435813,
#                 248.405066,
#                 1369.365473,
#                 712.546926,
#                 -196.214127,
#                 285.729881,
#                 518.166383,
#                 -614.53737,
#                 -351.37692,
#                 -443.603014,
#                 68.198539,
#                 -1039.593879,
#                 -2120.164136,
#                 849.273571,
#                 898.707921,
#                 863.10236,
#                 801.001314,
#                 1935.792068,
#                 1673.3895,
#                 2044.725385,
#                 1991.197929,
#                 1195.261165,
#                 null,
#                 null
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": "#93cc82",
#                 "opacity": 0.7
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u94f6\u884c\u4ee3\u5ba2\u8fdc\u671f\u7ed3\u552e\u6c47\u7b7e\u7ea6\u5dee\u989d",
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 368.0889,
#                 199.6808,
#                 288.638,
#                 412.4565,
#                 177.9711,
#                 129.9013,
#                 217.1607,
#                 311.5243,
#                 375.3983,
#                 582.9813,
#                 439.2752,
#                 526.1046,
#                 635.8996,
#                 251.6531,
#                 400.2721,
#                 489.2527,
#                 602.884,
#                 418.5162,
#                 401.4799,
#                 341.3841,
#                 163.8887,
#                 25.8551,
#                 -1.9247,
#                 15.3493,
#                 189.3675,
#                 48.1294,
#                 13.793,
#                 -67.7326,
#                 46.4449,
#                 -101.175,
#                 27.3742,
#                 -70.6959,
#                 65.464,
#                 24.6238,
#                 180.0673,
#                 508.7966,
#                 379.8589,
#                 232.0202,
#                 403.8838,
#                 268.1225,

# %%
grid.render('figure/银行结售汇差额、银行代客远期结售汇签约差额和美元兑人民币汇率.html')
# Out:
# 'c:\\Users\\siruo\\Documents\\每周工作\\汇率&股票&利率&部分宏观\\figure\\银行结售汇差额、银行代客远期结售汇签约差额和美元兑人民币汇率.html'

# %% [markdown]
# ## 利差与港汇

# %%
# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

data_file = '美元兑港币.xlsx'
data_path = os.path.join(data_dir, data_file)
US_HK_rate_table = pd.read_excel(data_path).dropna()
US_HK_rate_table.columns = ['Time', 'US_HK_rate']
US_HK_rate_table['Time'] = pd.to_datetime(US_HK_rate_table['Time'])

data_file = 'LIBOR_美元_3个月.xlsx'
data_path = os.path.join(data_dir, data_file)
libor_3M_table = pd.read_excel(data_path).dropna()
libor_3M_table.columns = ['Time', 'libor_3M']
libor_3M_table['Time'] = pd.to_datetime(libor_3M_table['Time'])

data_file = 'HIBOR_3个月.xlsx'
data_path = os.path.join(data_dir, data_file)
hibor_3M_table = pd.read_excel(data_path).dropna()
hibor_3M_table.columns = ['Time', 'hibor_3M']
hibor_3M_table['Time'] = pd.to_datetime(hibor_3M_table['Time'])
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 绘制折线图
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(libor_3M_table['Time'], libor_3M_table['libor_3M'], label='LIBOR 3M', color='#007896FF', linewidth=1)
ax.plot(hibor_3M_table['Time'], hibor_3M_table['hibor_3M'], label='HIBOR 3M', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')


# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('')

# 设置标题
ax.set_title('LIBOR 3M 与 HIBOR 3M')

plt.savefig("figure/LIBOR 3M 与 HIBOR 3M.png")

# 显示图形
plt.show()

# %%
split_year = 2019

US_HK_rate_table = US_HK_rate_table[US_HK_rate_table['Time'].dt.year >= split_year]
libor_3M_table = libor_3M_table[libor_3M_table['Time'].dt.year >= split_year]
hibor_3M_table = hibor_3M_table[hibor_3M_table['Time'].dt.year >= split_year]

# 合并数据框
Total3 = US_HK_rate_table.merge(libor_3M_table, on='Time') \
    .merge(hibor_3M_table, on='Time')

# 计算新变量
Total3['interest_spread_3M'] = Total3['libor_3M'] - Total3['hibor_3M']

mean_interest_spread_3M = Total3["interest_spread_3M"].mean()
sd_interest_spread_3M = Total3["interest_spread_3M"].std()

mean_US_HK_rate = Total3["US_HK_rate"].mean()
sd_US_HK_rate = Total3["US_HK_rate"].std()

# 计算US_CHN_rate_z
Total3['US_HK_rate_z'] = (Total3['US_HK_rate'] - Total3['US_HK_rate'].mean()) / Total3['US_HK_rate'].std()

# 计算y2
y2 = Total3['US_HK_rate_z'] * Total3['interest_spread_3M'].std() + Total3['interest_spread_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total3['Time'], Total3['interest_spread_3M'], label='LIBOR 3M 和 HIBOR 3M 之差%', color='#007896FF', linewidth=1)
ax.plot(Total3['Time'], y2, label='美元/港币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total3['interest_spread_3M'].mean()) / Total3['interest_spread_3M'].std() * Total3['US_HK_rate'].std() + Total3['US_HK_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('利差')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('LIBOR 3M 和 HIBOR 3M 之差与美元兑港币汇率')

plt.savefig("figure/LIBOR 3M 和 HIBOR 3M 之差与美元兑港币汇率.png")

# 显示图形
plt.show()
