# %% [markdown]
# ## 数据预处理
# ### Data Transform

# %%
import os
import pandas as pd

# 获取当前工作目录
cwd = os.getcwd()

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

# 指定输出目录
output_dir = os.path.join(cwd, 'data_csv')

# 如果输出目录不存在，则创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

"""
# 指定要读取数据的文件名
data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
# 指定输出文件名
output_file = '即期汇率_美元兑人民币.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

# data_file = '000300.SH-行情统计-20230714.xlsx'
# data_path = os.path.join(data_dir, data_file)
# df = pd.read_excel(data_path)
#df = df.dropna()
# df['交易日期'] = pd.to_datetime(df['交易日期'])
# output_file = '000300.SH-行情统计.csv'
# output_path = os.path.join(output_dir, output_file)
# df.to_csv(output_path, index = None, header = True)

data_file = '沪深300指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '沪深300指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

# data_file = 'SPX.GI-行情统计-20230714.xlsx'
# data_path = os.path.join(data_dir, data_file)
# df = pd.read_excel(data_path)
#df = df.dropna()
# df['交易日期'] = pd.to_datetime(df['交易日期'])
# output_file = 'SPX.GI-行情统计.csv'
# output_path = os.path.join(output_dir, output_file)
# df.to_csv(output_path, index = None, header = True)

data_file = '美国_标准普尔500指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_标准普尔500指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美元指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美元指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_10年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_10年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_2年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_2年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '中国_银行代客远期结售汇签约差额_人民币_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '中国_银行代客远期结售汇签约差额_人民币_当月值.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '中国_银行结售汇差额_当月值.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '中国_银行结售汇差额_当月值.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)
"""

data_file = 'MSCI新兴市场.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = 'MSCI新兴市场.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)
# Out:
# c:\Users\siruo\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ### Get Data

# %%
import datetime

today = str(datetime.date.today())

# %%
import akshare as ak

bond_zh_us_rate_df = ak.bond_zh_us_rate(start_date="2015-01-01")
CN_Y10_table = bond_zh_us_rate_df.loc[ : ,["日期","中国国债收益率10年"]].dropna()
CN_Y2_table = bond_zh_us_rate_df.loc[ : ,["日期","中国国债收益率2年"]].dropna()
US_Y10_table = bond_zh_us_rate_df.loc[ : ,["日期","美国国债收益率10年"]].dropna()
US_Y2_table = bond_zh_us_rate_df.loc[ : ,["日期","美国国债收益率2年"]].dropna()

CN_Y10_table.to_csv("data_csv/中国_国债收益率_10年.csv", index = None, header = True)
CN_Y2_table.to_csv("data_csv/中国_国债收益率_2年.csv", index = None, header = True)
US_Y10_table.to_csv("data_csv/美国_国债收益率_10年.csv", index = None, header = True)
US_Y2_table.to_csv("data_csv/美国_国债收益率_2年.csv", index = None, header = True)

# %%
CSI300_table = ak.index_zh_a_hist(symbol="000300", period="daily", start_date="2015-01-01", end_date=today)
CSI300_table.to_csv("data_csv/沪深300指数.csv", index = None, header = True)

# %%
LIBOR_3M_table = ak.rate_interbank(market="伦敦银行同业拆借市场", symbol="Libor美元", indicator="3月")
LIBOR_3M_table.to_csv("data_csv/LIBOR_美元_3个月.csv", index = None, header = True)

SHIBOR_3M_table = ak.rate_interbank(market="上海银行同业拆借市场", symbol="Shibor人民币", indicator="3月")
SHIBOR_3M_table.to_csv("data_csv/SHIBOR_3个月.csv", index = None, header = True)

HIBOR_3M_table = ak.rate_interbank(market="香港银行同业拆借市场", symbol="Hibor港币", indicator="3月")
HIBOR_3M_table.to_csv("data_csv/HIBOR_3个月.csv", index = None, header = True)

CNY_HIBOR_3M_table = ak.rate_interbank(market="香港银行同业拆借市场", symbol="Hibor人民币", indicator="3月")
CNY_HIBOR_3M_table.to_csv("data_csv/CNY_HIBOR_3个月.csv", index = None, header = True)

# %%
import yfinance as yf

def get_data_yfinance(start_date, end_date, symbol): # symbol是指标在Yahoo Finance上的代码
    ticker = yf.Ticker(symbol)
    ticker_data = ticker.history(start=start_date, end=end_date)
    ticker_data.reset_index(inplace=True)
    ticker_data['Date'] = ticker_data['Date'].dt.date
    return ticker_data

SPX_table = get_data_yfinance("2015-01-01", today, '^GSPC') # 标准普尔500指数
SPX_table.to_csv("data_csv/美国_标准普尔500指数.csv", index = None, header = True)

USDX_table = get_data_yfinance("2015-01-01", today, "DX-Y.NYB")
USDX_table.to_csv("data_csv/美元指数.csv", index = None, header = True)

USDCNY_table = get_data_yfinance("2015-01-01", today, "USDCNY=X")
USDCNY_table.to_csv("data_csv/USDCNY.csv", index = None, header = True)

#USDCNH_table = get_data_yfinance("2010-01-01", today, "CNH=X")
#USDCNH_table.to_csv("data_csv/USDCNH.csv", index = None, header = True)

#CNHHKD_table = get_data_yfinance("2010-01-01", today, "CNHHKD=X")
#CNHHKD_table.to_csv("data_csv/CNHHKD.csv", index = None, header = True)

USDHKD_table = get_data_yfinance("2007-01-01", today, "HKD=X")
USDHKD_table.to_csv("data_csv/USDHKD.csv", index = None, header = True)

# %%
'''
import pandas_datareader as pdr

def get_data_tiingo_by_pdr(start_date, end_date, symbol, api_key):
    os.environ["TIINGO_API_KEY"] = api_key
    ticker_data = pdr.get_data_tiingo(symbol, start=start_date, end=end_date, api_key=os.environ["TIINGO_API_KEY"])
    ticker_data.reset_index(inplace=True)
    ticker_data['date'] = ticker_data['date'].dt.date
    ticker_data.drop(columns=['symbol'], inplace=True)
    return ticker_data
    
api_key = "0f237dfdc622ccde20538a90d0a92ea81d0a741e" # 替换为您的API密钥
USDCNH_table = get_data_tiingo_by_pdr("2010-01-01", today, "USDCNH", api_key)
USDCNH_table.to_csv("data_csv/USDCNH.csv", index = None, header = True)
'''
# Out:
# '\nimport pandas_datareader as pdr\n\ndef get_data_tiingo_by_pdr(start_date, end_date, symbol, api_key):\n    os.environ["TIINGO_API_KEY"] = api_key\n    ticker_data = pdr.get_data_tiingo(symbol, start=start_date, end=end_date, api_key=os.environ["TIINGO_API_KEY"])\n    ticker_data.reset_index(inplace=True)\n    ticker_data[\'date\'] = ticker_data[\'date\'].dt.date\n    ticker_data.drop(columns=[\'symbol\'], inplace=True)\n    return ticker_data\n    \napi_key = "0f237dfdc622ccde20538a90d0a92ea81d0a741e" # 替换为您的API密钥\nUSDCNH_table = get_data_tiingo_by_pdr("2010-01-01", today, "USDCNH", api_key)\nUSDCNH_table.to_csv("data_csv/USDCNH.csv", index = None, header = True)\n'

# %% [markdown]
# ## 长线
#
# ### 股票与汇率

# %%
# 获取当前工作目录
cwd = os.getcwd()

# 判断是否存在figure文件夹，如果不存在就创建该文件夹
if not os.path.exists('figure'):
    os.makedirs('figure')

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

#data_file = '即期汇率_美元兑人民币.xlsx'
#data_path = os.path.join(data_dir, data_file)
#ER = pd.read_excel(data_path).dropna()
ER = pd.read_csv("data_csv/USDCNY.csv")
ER = ER.loc[:,['Date', 'Close']].dropna()
ER.columns = ['Time', 'exRate']
ER['Time'] = pd.to_datetime(ER['Time'])

#data_file = '美元指数.xlsx'
#data_path = os.path.join(data_dir, data_file)
#USDX = pd.read_excel(data_path).dropna()
USDX = pd.read_csv("data_csv/美元指数.csv")
USDX = USDX.loc[:,['Date', 'Close']].dropna()
USDX.columns = ['Time', 'Price_USDX']
USDX['Time'] = pd.to_datetime(USDX['Time'])

# 指定要读取数据的目录
# data_dir = os.path.join(cwd, 'data_csv')

# data_file = '000300.SH-行情统计.csv'
# data_path = os.path.join(data_dir, data_file)
# SH = pd.read_csv(data_path)
# SH = SH.loc[:,['交易日期', '收盘价']].dropna()
# SH.columns = ['Time', 'Price_SH']
# SH['Time'] = pd.to_datetime(SH['Time'])
# SH['Price_SH'] = SH['Price_SH'].str.replace(',', '').astype(float)

#data_file = '沪深300指数.xlsx'
#data_path = os.path.join(data_dir, data_file)
#SH = pd.read_excel(data_path).dropna()
SH = pd.read_csv("data_csv/沪深300指数.csv")
SH = SH.loc[:,['日期', '收盘']].dropna()
SH.columns = ['Time', 'Price_SH']
SH['Time'] = pd.to_datetime(SH['Time'])

# data_file = 'SPX.GI-行情统计.csv'
# data_path = os.path.join(data_dir, data_file)
# SPX = pd.read_csv(data_path)
# SPX = SPX.loc[:,['交易日期', '收盘价']].dropna()
# SPX.columns = ['Time', 'Price_SPX']
# SPX['Time'] = pd.to_datetime(SPX['Time'])
# SPX['Price_SPX'] = SPX['Price_SPX'].str.replace(',', '').astype(float)

#data_file = '美国_标准普尔500指数.xlsx'
#data_path = os.path.join(data_dir, data_file)
#SPX = pd.read_excel(data_path).dropna()
SPX = pd.read_csv("data_csv/美国_标准普尔500指数.csv")
SPX = SPX.loc[:,['Date', 'Close']].dropna()
SPX.columns = ['Time', 'Price_SPX']
SPX['Time'] = pd.to_datetime(SPX['Time'])

#data_file = 'MSCI新兴市场.xlsx'
#data_path = os.path.join(data_dir, data_file)
#MSCI = pd.read_excel(data_path).dropna()
MSCI = pd.read_csv('data_csv/MSCI新兴市场.csv').dropna()
MSCI.columns = ['Time', 'Price_MSCI']
MSCI['Time'] = pd.to_datetime(MSCI['Time'])

Total1 = ER.merge(SH, on='Time') \
    .merge(SPX, on='Time') \
    .merge(USDX, on='Time') \
    .merge(MSCI, on ='Time')

# Calculate stockRate
Total1['stockRate'] = Total1['Price_SPX'] / Total1['Price_SH'] * Total1['exRate']

"""
# Calculate means and standard deviations
mean_exRate = Total1['exRate'].mean()
sd_exRate = Total1['exRate'].std()

mean_stockRate = Total1['stockRate'].mean()
sd_stockRate = Total1['stockRate'].std()

mean_Price_USDX = Total1['Price_USDX'].mean()
sd_Price_USDX = Total1['Price_USDX'].std()

mean_Price_SH = Total1['Price_SH'].mean()
sd_Price_SH = Total1['Price_SH'].std()
"""

# 计算exRate_z
Total1['exRate_z'] = (Total1['exRate'] - Total1['exRate'].mean()) / Total1['exRate'].std()

# 计算USDX_z
Total1['USDX_z'] = (Total1['Price_USDX'] - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib.dates import DateFormatter, MonthLocator

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False

# 计算y2
y2 = Total1['exRate_z'] * Total1['stockRate'].std() + Total1['stockRate'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['stockRate'], label='美国标普500/沪深300（以美元计价）', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['stockRate'].mean()) / Total1['stockRate'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('美国标普500/沪深300（以美元计价）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('标普500和沪深300比值与美元兑人民币汇率')

# 保存图片
plt.savefig("figure/标普500和沪深300比值与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['exRate_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 添加参考线
#ax.axhline(y=0, color='gray', linestyle='--')
#ax.axvline(x=pd.to_datetime('2020-01-01'), color='gray', linestyle='--')

# 设置x轴刻度
#ax.xaxis.set_major_locator(plt.MaxNLocator(6))
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('沪深300指数收盘价与美元兑人民币汇率')

#plt.style.use('seaborn-whitegrid')

plt.savefig("figure/沪深300指数收盘价与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_USDX'], label='美元指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('美元指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美元指数收盘价与美元兑人民币汇率')

plt.savefig("figure/美元指数收盘价与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与沪深300指数')

plt.savefig("figure/美元指数与沪深300指数（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_MSCI'].std() + Total1['Price_MSCI'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total1['Time'], Total1['Price_MSCI'], label='MSCI新兴市场指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_MSCI'].mean()) / Total1['Price_MSCI'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('MSCI新兴市场指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与MSCI新兴市场指数')

plt.savefig("figure/美元指数与MSCI新兴市场指数（长线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ### 利差与汇率

# %%
# 获取当前工作目录
cwd = os.getcwd()

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

#data_file = '即期汇率_美元兑人民币.xlsx'
#data_path = os.path.join(data_dir, data_file)
#FXRate_table = pd.read_excel(data_path).dropna()
FXRate_table = pd.read_csv("data_csv/USDCNY.csv")
FXRate_table = FXRate_table.loc[:,['Date', 'Close']].dropna()
FXRate_table.columns = ['Time', 'US_CHN_rate']
FXRate_table['Time'] = pd.to_datetime(FXRate_table['Time'])

#data_file = '美国_国债收益率_10年.xlsx'
#data_path = os.path.join(data_dir, data_file)
#US_Y10_table = pd.read_excel(data_path).dropna()
US_Y10_table = pd.read_csv("data_csv/美国_国债收益率_10年.csv").dropna()
US_Y10_table.columns = ['Time', 'US_Y10']
US_Y10_table['Time'] = pd.to_datetime(US_Y10_table['Time'])

#data_file = '美国_国债收益率_2年.xlsx'
#data_path = os.path.join(data_dir, data_file)
#US_Y2_table = pd.read_excel(data_path).dropna()
US_Y2_table = pd.read_csv("data_csv/美国_国债收益率_2年.csv").dropna()
US_Y2_table.columns = ['Time', 'US_Y2']
US_Y2_table['Time'] = pd.to_datetime(US_Y2_table['Time'])

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_csv')

#data_file = '中国十年期国债收益率历史数据.csv'
#data_path = os.path.join(data_dir, data_file)
#CHN_Y10_table = pd.read_csv(data_path)
#CHN_Y10_table = CHN_Y10_table.iloc[:,0:2].dropna()
CHN_Y10_table = pd.read_csv("data_csv/中国_国债收益率_10年.csv").dropna()
CHN_Y10_table.columns = ['Time', 'CHN_Y10']
CHN_Y10_table['Time'] = pd.to_datetime(CHN_Y10_table['Time'])

#data_file = '中国二年期国债收益率历史数据.csv'
#data_path = os.path.join(data_dir, data_file)
#CHN_Y2_table = pd.read_csv(data_path)
#CHN_Y2_table = CHN_Y2_table.iloc[:,0:2].dropna()
CHN_Y2_table = pd.read_csv("data_csv/中国_国债收益率_2年.csv").dropna()
CHN_Y2_table.columns = ['Time', 'CHN_Y2']
CHN_Y2_table['Time'] = pd.to_datetime(CHN_Y2_table['Time'])

# 计算yearly_change_rate
FXRate_table['yearly_change_rate'] = (FXRate_table['US_CHN_rate'] - FXRate_table['US_CHN_rate'].shift(365)) / FXRate_table['US_CHN_rate'].shift(365)

# 删除缺失值
US_CHN_rate_table = FXRate_table.dropna()

# 合并数据框
Total2 = US_CHN_rate_table.merge(US_Y10_table, on='Time') \
    .merge(US_Y2_table, on='Time') \
    .merge(CHN_Y10_table, on='Time') \
    .merge(CHN_Y2_table, on='Time')

# 计算新变量
Total2['interest_spread_Y10'] = Total2['US_Y10'] - Total2['CHN_Y10']
Total2['interest_spread_Y2'] = Total2['US_Y2'] - Total2['CHN_Y2']
Total2['interest_spread_Y10_mod'] = Total2['US_Y10'] - Total2['CHN_Y10'] - Total2['yearly_change_rate']
Total2['interest_spread_Y2_mod'] = Total2['US_Y2'] - Total2['CHN_Y2'] - Total2['yearly_change_rate']

"""
mean_interest_spread_Y10 = Total2["interest_spread_Y10"].mean()
sd_interest_spread_Y10 = Total2["interest_spread_Y10"].std()

mean_interest_spread_Y2 = Total2["interest_spread_Y2"].mean()
sd_interest_spread_Y2 = Total2["interest_spread_Y2"].std()

mean_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].mean()
sd_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].std()

mean_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].mean()
sd_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].std()

mean_US_CHN_rate = Total2["US_CHN_rate"].mean()
sd_US_CHN_rate = Total2["US_CHN_rate"].std()
"""

# 计算US_CHN_rate_z
Total2['US_CHN_rate_z'] = (Total2['US_CHN_rate'] - Total2['US_CHN_rate'].mean()) / Total2['US_CHN_rate'].std()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10'].std() + Total2['interest_spread_Y10'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10'], label='美中10年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10'].mean()) / Total2['interest_spread_Y10'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10_mod'].std() + Total2['interest_spread_Y10_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10_mod'], label='美中10年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10_mod'].mean()) / Total2['interest_spread_Y10_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2'].std() + Total2['interest_spread_Y2'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2'], label='美中2年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2'].mean()) / Total2['interest_spread_Y2'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2_mod'].std() + Total2['interest_spread_Y2_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(13, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=3))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2_mod'].mean()) / Total2['interest_spread_Y2_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（长线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ## 短线
#
# ### 股票与汇率

# %%
split_year = 2020
split_date = "2020-01-01"

#ER = ER[ER['Time'].dt.year >= split_year]
ER.query("Time.dt.year >= @split_year", inplace=True)
#ER.query("Time >= @split_date", inplace=True)

#USDX = USDX[USDX['Time'].dt.year >= split_year]
USDX.query("Time.dt.year >= @split_year", inplace=True)
#USDX.query("Time >= @split_date", inplace=True)

#SH = SH[SH['Time'].dt.year >= split_year]
SH.query("Time.dt.year >= @split_year", inplace=True)
#SH.query("Time >= @split_date", inplace=True)

#SPX = SPX[SPX['Time'].dt.year >= split_year]
SPX.query("Time.dt.year >= @split_year", inplace=True)
#SPX.query("Time >= @split_date", inplace=True)

#MSCI = MSCI[MSCI['Time'].dt.year >= split_year]
MSCI.query("Time.dt.year >= @split_year", inplace=True)
#MSCI.query("Time >= @split_date", inplace=True)

Total1 = ER.merge(SH, on='Time') \
    .merge(SPX, on='Time') \
    .merge(USDX, on='Time') \
    .merge(MSCI, on='Time')

# Calculate stockRate
Total1['stockRate'] = Total1['Price_SPX'] / Total1['Price_SH'] * Total1['exRate']

"""
# Calculate means and standard deviations
mean_exRate = Total1['exRate'].mean()
sd_exRate = Total1['exRate'].std()

mean_stockRate = Total1['stockRate'].mean()
sd_stockRate = Total1['stockRate'].std()

mean_Price_USDX = Total1['Price_USDX'].mean()
sd_Price_USDX = Total1['Price_USDX'].std()

mean_Price_SH = Total1['Price_SH'].mean()
sd_Price_SH = Total1['Price_SH'].std()
"""

# 计算exRate_z
Total1['exRate_z'] = (Total1['exRate'] - Total1['exRate'].mean()) / Total1['exRate'].std()

# 计算USDX_z
Total1['USDX_z'] = (Total1['Price_USDX'] - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['stockRate'].std() + Total1['stockRate'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['stockRate'], label='美国标普500/沪深300（以美元计价）', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['stockRate'].mean()) / Total1['stockRate'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('美国标普500/沪深300（以美元计价）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('标普500和沪深300比值与美元兑人民币汇率')

plt.savefig("figure/标普500和沪深300比值与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['exRate_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 添加参考线
#ax.axhline(y=0, color='gray', linestyle='--')
#ax.axvline(x=pd.to_datetime('2020-01-01'), color='gray', linestyle='--')

# 设置x轴刻度
#ax.xaxis.set_major_locator(plt.MaxNLocator(6))
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('沪深300指数收盘价与美元兑人民币汇率')

#plt.style.use('seaborn-whitegrid')

plt.savefig("figure/沪深300指数收盘价与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total1['exRate_z'] * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_USDX'], label='美元指数收盘价', color='#007896FF', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total1['Price_USDX'].mean()) / Total1['Price_USDX'].std() * Total1['exRate'].std() + Total1['exRate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('美元指数收盘价')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美元指数收盘价与美元兑人民币汇率')

plt.savefig("figure/美元指数收盘价与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_SH'].std() + Total1['Price_SH'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_SH'], label='沪深300指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_SH'].mean()) / Total1['Price_SH'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('沪深300指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与沪深300指数')

plt.savefig("figure/美元指数与沪深300指数（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = -Total1['USDX_z'] * Total1['Price_MSCI'].std() + Total1['Price_MSCI'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total1['Time'], Total1['Price_MSCI'], label='MSCI新兴市场指数', color='#db6968', linewidth=1)
ax.plot(Total1['Time'], y2, label='美元指数', color='#007896FF', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (-y + Total1['Price_MSCI'].mean()) / Total1['Price_MSCI'].std() * Total1['Price_USDX'].std() + Total1['Price_USDX'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('MSCI新兴市场指数')
ax2.set_ylabel('美元指数')

# 设置标题
ax.set_title('美元指数与MSCI新兴市场指数')

plt.savefig("figure/美元指数与MSCI新兴市场指数（短线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ### 利差与汇率

# %%
#FXRate_table = FXRate_table[FXRate_table['Time'].dt.year >= split_year]
FXRate_table.query("Time.dt.year >= @split_year", inplace=True)
#FXRate_table.query("Time >= @split_date", inplace=True)

#US_Y10_table = US_Y10_table[US_Y10_table['Time'].dt.year >= split_year]
US_Y10_table.query("Time.dt.year >= @split_year", inplace=True)
#US_Y10_table.query("Time >= @split_date", inplace=True)

#US_Y2_table = US_Y2_table[US_Y2_table['Time'].dt.year >= split_year]
US_Y2_table.query("Time.dt.year >= @split_year", inplace=True)
#US_Y2_table.query("Time >= @split_date", inplace=True)

#CHN_Y10_table = CHN_Y10_table[CHN_Y10_table['Time'].dt.year >= split_year]
CHN_Y10_table.query("Time.dt.year >= @split_year", inplace=True)
#CHN_Y10_table.query("Time >= @split_date", inplace=True)

#CHN_Y2_table = CHN_Y2_table[CHN_Y2_table['Time'].dt.year >= split_year]
CHN_Y2_table.query("Time.dt.year >= @split_year", inplace=True)
#CHN_Y2_table.query("Time >= @split_date", inplace=True)

# 计算yearly_change_rate
FXRate_table['yearly_change_rate'] = (FXRate_table['US_CHN_rate'] - FXRate_table['US_CHN_rate'].shift(365)) / FXRate_table['US_CHN_rate'].shift(365)

# 删除缺失值
US_CHN_rate_table = FXRate_table.dropna()

# 合并数据框
Total2 = US_CHN_rate_table.merge(US_Y10_table, on='Time') \
    .merge(US_Y2_table, on='Time') \
    .merge(CHN_Y10_table, on='Time') \
    .merge(CHN_Y2_table, on='Time')

# 计算新变量
Total2['interest_spread_Y10'] = Total2['US_Y10'] - Total2['CHN_Y10']
Total2['interest_spread_Y2'] = Total2['US_Y2'] - Total2['CHN_Y2']
Total2['interest_spread_Y10_mod'] = Total2['US_Y10'] - Total2['CHN_Y10'] - Total2['yearly_change_rate']
Total2['interest_spread_Y2_mod'] = Total2['US_Y2'] - Total2['CHN_Y2'] - Total2['yearly_change_rate']

"""
mean_interest_spread_Y10 = Total2["interest_spread_Y10"].mean()
sd_interest_spread_Y10 = Total2["interest_spread_Y10"].std()

mean_interest_spread_Y2 = Total2["interest_spread_Y2"].mean()
sd_interest_spread_Y2 = Total2["interest_spread_Y2"].std()

mean_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].mean()
sd_interest_spread_Y10_mod = Total2["interest_spread_Y10_mod"].std()

mean_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].mean()
sd_interest_spread_Y2_mod = Total2["interest_spread_Y2_mod"].std()

mean_US_CHN_rate = Total2["US_CHN_rate"].mean()
sd_US_CHN_rate = Total2["US_CHN_rate"].std()
"""

# 计算US_CHN_rate_z
Total2['US_CHN_rate_z'] = (Total2['US_CHN_rate'] - Total2['US_CHN_rate'].mean()) / Total2['US_CHN_rate'].std()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10'].std() + Total2['interest_spread_Y10'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10'], label='美中10年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10'].mean()) / Total2['interest_spread_Y10'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y10_mod'].std() + Total2['interest_spread_Y10_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y10_mod'], label='美中10年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y10_mod'].mean()) / Total2['interest_spread_Y10_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('10年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中10年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中10年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2'].std() + Total2['interest_spread_Y2'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2'].mean()) / Total2['interest_spread_Y2'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %%
# 计算y2
y2 = Total2['US_CHN_rate_z'] * Total2['interest_spread_Y2_mod'].std() + Total2['interest_spread_Y2_mod'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(Total2['Time'], Total2['interest_spread_Y2_mod'], label='美中2年期国债收益率之差（经过汇率调整）', color='#007896FF', linewidth=1)
ax.plot(Total2['Time'], y2, label='美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total2['interest_spread_Y2_mod'].mean()) / Total2['interest_spread_Y2_mod'].std() * Total2['US_CHN_rate'].std() + Total2['US_CHN_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('2年期国债收益率之差%（汇率调整）')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('美中2年期国债收益率之差与美元兑人民币汇率')

plt.savefig("figure/美中2年期国债收益率之差（经过汇率调整）与美元兑人民币汇率（短线）.png")

# 显示图形
plt.show()

# %% [markdown]
# ## 利差与港汇

# %%
# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

#data_file = '美元兑港币.xlsx'
#data_path = os.path.join(data_dir, data_file)
#US_HK_rate_table = pd.read_excel(data_path).dropna()
US_HK_rate_table = pd.read_csv("data_csv/USDHKD.csv")
US_HK_rate_table = US_HK_rate_table.loc[:,['Date', 'Close']].dropna()
US_HK_rate_table.columns = ['Time', 'US_HK_rate']
US_HK_rate_table['Time'] = pd.to_datetime(US_HK_rate_table['Time'])

#data_file = 'LIBOR_美元_3个月.xlsx'
#data_path = os.path.join(data_dir, data_file)
#libor_3M_table = pd.read_excel(data_path).dropna()
libor_3M_table = pd.read_csv("data_csv/LIBOR_美元_3个月.csv")
libor_3M_table = libor_3M_table.loc[:,['报告日', '利率']].dropna()
libor_3M_table.columns = ['Time', 'libor_3M']
libor_3M_table['Time'] = pd.to_datetime(libor_3M_table['Time'])
libor_3M_table.query("Time >= '2007-01-01'", inplace=True)

#data_file = 'HIBOR_3个月.xlsx'
#data_path = os.path.join(data_dir, data_file)
#hibor_3M_table = pd.read_excel(data_path).dropna()
hibor_3M_table = pd.read_csv("data_csv/HIBOR_3个月.csv")
hibor_3M_table = hibor_3M_table.loc[:,['报告日', '利率']].dropna()
hibor_3M_table.columns = ['Time', 'hibor_3M']
hibor_3M_table['Time'] = pd.to_datetime(hibor_3M_table['Time'])
hibor_3M_table.query("Time >= '2007-01-01'", inplace=True)

shibor_3M_table = pd.read_csv("data_csv/SHIBOR_3个月.csv")
shibor_3M_table = shibor_3M_table.loc[:,['报告日', '利率']].dropna()
shibor_3M_table.columns = ['Time', 'shibor_3M']
shibor_3M_table['Time'] = pd.to_datetime(shibor_3M_table['Time'])
shibor_3M_table.query("Time >= '2007-01-01'", inplace=True)

CNY_hibor_3M_table = pd.read_csv("data_csv/CNY_HIBOR_3个月.csv")
CNY_hibor_3M_table = CNY_hibor_3M_table.loc[:,['报告日', '利率']].dropna()
CNY_hibor_3M_table.columns = ['Time', 'CNY_hibor_3M']
CNY_hibor_3M_table['Time'] = pd.to_datetime(CNY_hibor_3M_table['Time'])

USDCNH_table = pd.read_excel("data_xlsx/Exchange Rate Daily Historical Data_bbg.xlsx", sheet_name='USDCNH', skiprows=[0,1,2,3,4])
USDCNH_table = USDCNH_table.loc[:,['Dates', 'PX_LAST']].dropna()
USDCNH_table.columns = ['Time', 'USDCNH']
USDCNH_table['Time'] = pd.to_datetime(USDCNH_table['Time'])

CNHHKD_table = pd.read_excel("data_xlsx/Exchange Rate Daily Historical Data_bbg.xlsx", sheet_name='CNHHKD', skiprows=[0,1,2,3,4])
CNHHKD_table = CNHHKD_table.loc[:,['Dates', 'PX_LAST']].dropna()
CNHHKD_table.columns = ['Time', 'CNHHKD']
CNHHKD_table['Time'] = pd.to_datetime(CNHHKD_table['Time'])

# %%
# 绘制折线图
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(libor_3M_table['Time'], libor_3M_table['libor_3M'], label='LIBOR 3M', color='#007896FF', linewidth=1)
ax.plot(hibor_3M_table['Time'], hibor_3M_table['hibor_3M'], label='HIBOR 3M', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')


# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('')

# 设置标题
ax.set_title('LIBOR 3M 与 HIBOR 3M')

plt.savefig("figure/LIBOR 3M 与 HIBOR 3M.png")

# 显示图形
plt.show()

# %%
# 绘制折线图
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(shibor_3M_table['Time'], shibor_3M_table['shibor_3M'], label='SHIBOR 3M', color='#93cc82', linewidth=1)
ax.plot(CNY_hibor_3M_table['Time'], CNY_hibor_3M_table['CNY_hibor_3M'], label='CNY HIBOR 3M', color="#5793f3", linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')


# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('')

# 设置标题
ax.set_title('SHIBOR 3M 与 CNY HIBOR 3M')

plt.savefig("figure/SHIBOR 3M 与 CNY HIBOR 3M.png")

# 显示图形
plt.show()

# %%
Total4 = USDCNH_table.merge(libor_3M_table, on='Time') \
    .merge(shibor_3M_table, on='Time')

Total4['interest_spread_3M'] = Total4['libor_3M'] - Total4['shibor_3M']

Total4['USDCNH_z'] = (Total4['USDCNH'] - Total4['USDCNH'].mean()) / Total4['USDCNH'].std()

# 计算y2
y2 = Total4['USDCNH_z'] * Total4['interest_spread_3M'].std() + Total4['interest_spread_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total4['Time'], Total4['interest_spread_3M'], label='LIBOR 3M 和 SHIBOR 3M 之差%', color='#007896FF', linewidth=1)
ax.plot(Total4['Time'], y2, label='离岸美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total4['interest_spread_3M'].mean()) / Total4['interest_spread_3M'].std() * Total4['USDCNH'].std() + Total4['USDCNH'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper left')
ax.set_xlabel('')
ax.set_ylabel('利差')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('LIBOR 3M 和 SHIBOR 3M 之差与离岸美元兑人民币汇率')

plt.savefig("figure/LIBOR 3M 和 SHIBOR 3M 之差与离岸美元兑人民币汇率.png")

# 显示图形
plt.show()

# %%
Total5 = CNHHKD_table.merge(hibor_3M_table, on='Time') \
    .merge(shibor_3M_table, on='Time')

Total5['interest_spread_3M'] = Total5['shibor_3M'] - Total5['hibor_3M']

Total5['CNHHKD_z'] = (Total5['CNHHKD'] - Total5['CNHHKD'].mean()) / Total5['CNHHKD'].std()

# 计算y2
y2 = Total5['CNHHKD_z'] * Total5['interest_spread_3M'].std() + Total5['interest_spread_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total5['Time'], Total5['interest_spread_3M'], label='SHIBOR 3M 和 HIBOR 3M 之差%', color='#007896FF', linewidth=1)
ax.plot(Total5['Time'], y2, label='离岸人民币/港币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total5['interest_spread_3M'].mean()) / Total5['interest_spread_3M'].std() * Total5['CNHHKD'].std() + Total5['CNHHKD'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('利差')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('SHIBOR 3M 和 HIBOR 3M 之差与离岸人民币兑港币汇率')

plt.savefig("figure/SHIBOR 3M 和 HIBOR 3M 之差与离岸人民币兑港币汇率.png")

# 显示图形
plt.show()

# %%
Total6 = CNHHKD_table.merge(CNY_hibor_3M_table, on='Time') \
    .merge(shibor_3M_table, on='Time')

Total6['interest_spread_3M'] = Total6['shibor_3M'] - Total6['CNY_hibor_3M']

Total6['CNHHKD_z'] = (Total6['CNHHKD'] - Total6['CNHHKD'].mean()) / Total6['CNHHKD'].std()

# 计算y2
y2 = Total6['CNHHKD_z'] * Total6['interest_spread_3M'].std() + Total6['interest_spread_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total6['Time'], Total6['interest_spread_3M'], label='SHIBOR 3M 和 CNY HIBOR 3M 之差%', color='#007896FF', linewidth=1)
ax.plot(Total6['Time'], y2, label='离岸人民币/港币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total6['interest_spread_3M'].mean()) / Total6['interest_spread_3M'].std() * Total6['CNHHKD'].std() + Total6['CNHHKD'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('利差')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('SHIBOR 3M 和 CNY HIBOR 3M 之差与离岸人民币兑港币汇率')

plt.savefig("figure/SHIBOR 3M 和 CNY HIBOR 3M 之差与离岸人民币兑港币汇率.png")

# 显示图形
plt.show()

# %%
Total7 = USDCNH_table.merge(CNY_hibor_3M_table, on='Time')

Total7['USDCNH_z'] = (Total7['USDCNH'] - Total7['USDCNH'].mean()) / Total7['USDCNH'].std()

# 计算y2
y2 = Total7['USDCNH_z'] * Total7['CNY_hibor_3M'].std() + Total7['CNY_hibor_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total7['Time'], Total7['CNY_hibor_3M'], label='CNY HIBOR 3M', color='#007896FF', linewidth=1)
ax.plot(Total7['Time'], y2, label='离岸美元/人民币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=6))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total7['CNY_hibor_3M'].mean()) / Total7['CNY_hibor_3M'].std() * Total7['USDCNH'].std() + Total7['USDCNH'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper right')
ax.set_xlabel('')
ax.set_ylabel('利率')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('CNY HIBOR 3M 与离岸美元兑人民币汇率')

plt.savefig("figure/CNY HIBOR 3M 与离岸美元兑人民币汇率.png")

# 显示图形
plt.show()

# %%
split_year2 = 2019
split_date2 = "2019-01-01"

#US_HK_rate_table = US_HK_rate_table[US_HK_rate_table['Time'].dt.year >= split_year]
US_HK_rate_table.query("Time.dt.year >= @split_year2", inplace=True)
#US_HK_rate_table.query("Time >= @split_date2", inplace=True)

#libor_3M_table = libor_3M_table[libor_3M_table['Time'].dt.year >= split_year2]
libor_3M_table.query("Time.dt.year >= @split_year2", inplace=True)
#libor_3M_table.query("Time >= @split_date2", inplace=True)

#hibor_3M_table = hibor_3M_table[hibor_3M_table['Time'].dt.year >= split_year2]
hibor_3M_table.query("Time.dt.year >= @split_year2", inplace=True)
#hibor_3M_table.query("Time >= @split_date2", inplace=True)

# 合并数据框
Total3 = US_HK_rate_table.merge(libor_3M_table, on='Time') \
    .merge(hibor_3M_table, on='Time')

# 计算新变量
Total3['interest_spread_3M'] = Total3['libor_3M'] - Total3['hibor_3M']

mean_interest_spread_3M = Total3["interest_spread_3M"].mean()
sd_interest_spread_3M = Total3["interest_spread_3M"].std()

mean_US_HK_rate = Total3["US_HK_rate"].mean()
sd_US_HK_rate = Total3["US_HK_rate"].std()

Total3['US_HK_rate_z'] = (Total3['US_HK_rate'] - Total3['US_HK_rate'].mean()) / Total3['US_HK_rate'].std()

# 计算y2
y2 = Total3['US_HK_rate_z'] * Total3['interest_spread_3M'].std() + Total3['interest_spread_3M'].mean()

# 绘制折线图
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(Total3['Time'], Total3['interest_spread_3M'], label='LIBOR 3M 和 HIBOR 3M 之差%', color='#007896FF', linewidth=1)
ax.plot(Total3['Time'], y2, label='美元/港币', color='#db6968', linewidth=1)

# 设置x轴刻度
ax.xaxis.set_major_locator(MonthLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# 设置y轴次坐标轴
def y2y2(y):
    return (y - Total3['interest_spread_3M'].mean()) / Total3['interest_spread_3M'].std() * Total3['US_HK_rate'].std() + Total3['US_HK_rate'].mean()
ax2 = ax.secondary_yaxis('right', functions=(y2y2, y2y2))

# 设置图例和坐标轴标签
ax.legend(loc='upper center')
ax.set_xlabel('')
ax.set_ylabel('利差')
ax2.set_ylabel('汇率')

# 设置标题
ax.set_title('LIBOR 3M 和 HIBOR 3M 之差与美元兑港币汇率')

plt.savefig("figure/LIBOR 3M 和 HIBOR 3M 之差与美元兑港币汇率.png")

# 显示图形
plt.show()
